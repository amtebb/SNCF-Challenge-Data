# %%
import pandas as pd
from preprocess import encode_df

# %%
df_x,df_y=pd.read_csv('x_train_final.csv'), pd.read_csv('y_train_final_j5KGWWK.csv')
df_x['p0q0']=df_y['p0q0']
df=df_x
df = df[~df.isna().any(axis=1)]
df=encode_df(df)
X=df[['train_std','train_mean','gare','day','hour','arret','p2q0','p3q0','p4q0','p0q2','p0q3','p0q4','p0q0']]
y=df['p0q0']

# %%
X_train=pd.read_csv('x_train_final.csv')
X_test=pd.read_csv('x_test_final.csv')

gares_x_train = set(X_train['gare'])
gares_x_test = set(X_test['gare'])

gares_only_in_train = gares_x_train - gares_x_test
gares_only_in_test = gares_x_test - gares_x_train

print("Gares only in X_train:", gares_only_in_train)
print("Gares only in X_test:", gares_only_in_test)
# Out:
# Gares only in X_train: {'TXR', 'BKS', 'OUA'}
# Gares only in X_test: set()

# %%
train_x_train = set(X_train['train'])
train_x_test = set(X_test['train'])

train_only_in_train = train_x_train - train_x_test
train_only_in_test = train_x_test - train_x_train

print("Gares only in X_train:", train_only_in_train)
print("Gares only in X_test:", train_only_in_test)
# Out:
# Gares only in X_train: {'DSZLSF', 'IKHPZL', 'CQNHBE', 'KMUUYB', 'QTPTKU', 'TSCYDW', 'WGFSOD', 'TLABRX', 'CBZIHI', 'HFPZHI', 'PKAJEC', 'JTMTAL', 'OBIUNC', 'LCEVAP', 'XYFECN', 'CVMOOV', 'WUEYXT', 'VSGZDA', 'DJIMGL', 'IJBCPL', 'OKSEMP', 'YXRASL', 'AAJNIJ', 'DJAUHF', 'PLYYES', 'LUWFLV', 'QSFHYM', 'UXZVNM', 'ZFZNRK', 'GUAFSR', 'VGCVFM', 'EVTGSY', 'ZWCTRV', 'FTYMLQ', 'GQPKAU', 'MGNXUM', 'POBWXG', 'QCIHIC', 'LBQQOV', 'NEOCGF', 'DSPQIS', 'TTIXIX', 'WAPEYI', 'XBAZHE', 'EPRWPL', 'HPLOCK', 'SIPVMI', 'GAUFON', 'IBJRIT', 'ZRKAFZ', 'MJELFP', 'VKQPPB', 'DKOQTK', 'QHQGYA', 'OSCITJ', 'DMSALV', 'FGHKXB', 'FPUHVK', 'DPNQUO', 'DYSEBF', 'XGVZWZ', 'KMCUFS', 'HNPMNA', 'YSIDHG', 'EXLNQO', 'SVTKJJ', 'WFXEQD', 'UHTPAU', 'VXGBMY', 'VFUIRX', 'XECXQV', 'WVPFQB', 'YMKPFL', 'YHLWMI', 'THSTJY', 'DZWKTV', 'CHWKDX', 'EUKVYL', 'PBATRC', 'AJMJXA', 'RWNVMJ', 'RALTCX', 'FHXCNS', 'RPBCNR', 'OGPNXJ', 'JJMHCD', 'OGLBVW', 'ZGSACM', 'ZPRSPA', 'ILOLLO', 'NPFZEY', 'BGULEQ', 'IVOUZK', 'JOQIST', 'FGDUMD', 'AYPKXQ', 'UIEMXJ', 'ZKK
# ...

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.metrics import mean_squared_error, accuracy_score
from sklearn.model_selection import RandomizedSearchCV

# %%
df_2=df.groupby('train')['']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 2
#       1 df_2=df.groupby('train')
# ----> 2 df_2['p0q0'].mean()
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/site-packages/pandas/core/groupby/generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/site-packages/pandas/core/base.py:244, in SelectionMixin.__getitem__(self, key)
#     242 else:
#     243     if key not in self.obj:
# ...

# %% [markdown]
# # Préprocess

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 5
#       3 encoder = OneHotEncoder()
#       4 gare_encoded = encoder.fit_transform(df[['gare']])
# ----> 5 gare_df = pd.DataFrame(gare_encoded, columns=[f'gare_{i}' for i in range(gare_encoded.shape[1])])
#       7 X = pd.concat([df[['p2q0', 'p3q0', 'p4q0', 'p0q2', 'p0q3', 'p0q4', 'arret']], gare_df], axis=1)
#       8 X.head()
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/site-packages/pandas/core/frame.py:867, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     859         mgr = arrays_to_mgr(
#     860             arrays,
#     861             columns,
#    (...)
#     864             typ=manager,
#     865         )
#     866     else:
# --> 867         mgr = ndarray_to_mgr(
#     868             data,
#     869             index,
#     870             columns,
# ...
